# %% [markdown]
# <a href="https://colab.research.google.com/github/mohammed-raihan/udl-book/blob/main/Notebooks/Chap10/10_2_Convolution_for_MNIST_1D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 10.2: Convolution for MNIST-1D**
#
# This notebook investigates a 1D convolutional network for MNIST-1D

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-iqy5t9zx
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-iqy5t9zx
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2026.1.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14664 sha256=018d614d901319f3e610b912b2cee5d3930311aa9f57d0e479368f9751f0dfe5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2xoorcox/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
print(type(data))
print(data.keys())
print(np.shape(data['x']))
print(np.shape(data['y']))
# Out:
# <class 'dict'>
# dict_keys(['x', 'x_test', 'y', 'y_test', 't', 'templates'])
# (4000, 40)
# (4000,)

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# TODO Create a model with the following layers
# 1. Convolutional layer, (input=length 40 and 1 channel, kernel size 3, stride 2, padding="valid", 15 output channels )
# 2. ReLU
# 3. Convolutional layer, (input=length 19 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels )
# 4. ReLU
# 5. Convolutional layer, (input=length 9 and 15 channels, kernel size 3, stride 2, padding="valid", 15 output channels)
# 6. ReLU
# 7. Flatten (converts 4x15) to length 60
# 8. Linear layer (input size = 60, output size = 10)
# References:
# https://pytorch.org/docs/1.13/generated/torch.nn.Conv1d.html?highlight=conv1d#torch.nn.Conv1d
# https://pytorch.org/docs/stable/generated/torch.nn.Flatten.html
# https://pytorch.org/docs/1.13/generated/torch.nn.Linear.html?highlight=linear#torch.nn.Linear

# NOTE THAT THE CONVOLUTIONAL LAYERS NEED TO TAKE THE NUMBER OF INPUT CHANNELS AS A PARAMETER
# AND NOT THE INPUT SIZE.


# Replace the following function:
model = nn.Sequential(
nn.Conv1d(
    in_channels=1,
    out_channels=15,
    kernel_size=3,
    stride=2,
    padding=0
    ),
nn.ReLU(),
nn.Conv1d(
    in_channels=15,
    out_channels=15,
    kernel_size=3,
    stride=2,
    padding=0
    ),
nn.ReLU(),
nn.Conv1d(
    in_channels=15,
    out_channels=15,
    kernel_size=3,
    stride=2,
    padding=0
    ),
nn.ReLU(),
nn.Flatten(),
nn.Linear(60, 10),
)


# 1. Create dummy input: (Batch Size, Channels, Length)
x = torch.randn(1, 1, 40)

# 2. Forward pass
output = model(x)

# 3. Check shape
print(f"Input shape: {x.shape}")
print(f"Output shape: {output.shape}") # Should be [1, 10]
# Out:
# Input shape: torch.Size([1, 1, 40])
# Output shape: torch.Size([1, 10])

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# create 100 dummy data points and store in data loader class
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long')).long()
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long')).long()

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch[:,None,:])
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train[:,None,:])
  pred_val = model(x_val[:,None,:])
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()

# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='validation')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('Part I: Validation Result %3.2f'%(errors_val[-1]))
ax.legend()
plt.show()
# Out:
# Epoch     0, train loss 2.111897, train error 83.12,  val loss 2.115883, percent error 84.00
# Epoch     1, train loss 1.674652, train error 68.55,  val loss 1.682489, percent error 69.60
# Epoch     2, train loss 1.361049, train error 54.10,  val loss 1.374409, percent error 57.10
# Epoch     3, train loss 1.239626, train error 50.40,  val loss 1.279818, percent error 55.10
# Epoch     4, train loss 1.254039, train error 52.85,  val loss 1.277142, percent error 54.90
# Epoch     5, train loss 1.128964, train error 47.12,  val loss 1.160435, percent error 50.50
# Epoch     6, train loss 1.045702, train error 42.92,  val loss 1.102257, percent error 47.00
# Epoch     7, train loss 0.960595, train error 39.35,  val loss 1.020203, percent error 41.50
# Epoch     8, train loss 0.889397, train error 35.95,  val loss 0.937042, percent error 37.30
# Epoch     9, train loss 0.790123, train error 30.60,  val loss 0.828255, percent error 30.40
# Epoch    10, train loss 0.730255, train error 27.38,  val loss 0.795239, percent error 30.50
# Epoch    11, train loss 0.590483, train error 21.57,  val loss 0.671265, percent error 24.40
# Epoch    12, train loss 0.522745, train error 20.12,  val loss 0.597744, percent error 22.90
# Epoch    13, train loss 0.493204, train error 18.90,  val loss 0.574877, percent error 21.70
# Epoch    14, train loss 0.485199, train error 17.65,  val loss 0.592674, percent error 21.10
# Epoch    15, train loss 0.404102, train error 15.12,  val loss 0.505489, percent error 18.50
# Epoch    16, train loss 0.440467, train error 15.20,  val loss 0.511422, percent error 17.20
# Epoch    17, train loss 0.329789, train error 10.88,  val loss 0.414087, percent error 14.30
# Epoch    18, train loss 0.245893, train error 8.75,  val loss 0.353229, percent error 11.40
# Epoch    19, train loss 0.224291, train error 7.43,  val loss 0.335030, percent error 10.80
# Epoch    20, train loss 0.183301, train error 5.70,  val loss 0.299652, percent error 10.00
# Epoch    21, train loss 0.169791, train error 5.45,  val loss 0.292494, percent error 10.00
# Epoch    22, train loss 0.153613, train error 4.80,  val loss 0.294284, percent error 10.00
# Epoch    23, train loss 0.171784, train error 5.65,  val loss 0.316852, percent error 10.70
# Epoch    24, train loss 0.138206, train error 4.47,  val loss 0.286190, percent error 8.30
# Epoch    25, train loss 0.144652, train error 4.95,  val loss 0.314723, percent error 9.90
# Epoch    26, train loss 0.126650, train error 3.82,  val loss 0.292529, percent error 8.30
# Epoch    27, train loss 0.145574, train error 4.80,  val loss 0.312689, percent error 9.70
# Epoch    28, train loss 0.123491, train error 3.88,  val loss 0.294478, percent error 8.70
# Epoch    29, train loss 0.115860, train error 3.60,  val loss 0.282099, percent error 8.50
# Epoch    30, train loss 0.104818, train error 3.15,  val loss 0.297326, percent error 9.10
# Epoch    31, train loss 0.103207, train error 3.25,  val loss 0.295933, percent error 8.90
# Epoch    32, train loss 0.087595, train error 2.25,  val loss 0.278605, percent error 8.20
# Epoch    33, train loss 0.082876, train error 1.97,  val loss 0.275435, percent error 8.30
# Epoch    34, train loss 0.081250, train error 2.18,  val loss 0.285382, percent error 9.20
# Epoch    35, train loss 0.079115, train error 2.22,  val loss 0.295126, percent error 9.80
# Epoch    36, train loss 0.075936, train error 2.05,  val loss 0.293660, percent error 8.60
# Epoch    37, train loss 0.083603, train error 2.35,  val loss 0.329865, percent error 9.40
# Epoch    38, train loss 0.082525, train error 2.40,  val loss 0.326132, percent error 8.70
# Epoch    39, train loss 0.075046, train error 2.25,  val loss 0.295300, percent error 8.70
# Epoch    40, train loss 0.060847, train error 1.47,  val loss 0.294078, percent error 8.50
# Epoch    41, train loss 0.058167, train error 1.38,  val loss 0.296578, percent error 8.40
# Epoch    42, train loss 0.054824, train error 1.28,  val loss 0.300709, percent error 8.90
# Epoch    43, train loss 0.055813, train error 1.32,  val loss 0.304494, percent error 8.50
# Epoch    44, train loss 0.051663, train error 1.20,  val loss 0.309467, percent error 8.20
# Epoch    45, train loss 0.057564, train error 1.47,  val loss 0.325109, percent error 9.00
# Epoch    46, train loss 0.053579, train error 1.35,  val loss 0.331765, percent error 9.80
# Epoch    47, train loss 0.050374, train error 1.12,  val loss 0.329245, percent error 9.40
# Epoch    48, train loss 0.044932, train error 0.80,  val loss 0.321372, percent error 8.50
# Epoch    49, train loss 0.044198, train error 0.90,  val loss 0.318197, percent error 8.70
# Epoch    50, train loss 0.045018, train error 0.97,  val loss 0.328470, percent error 8.90
# Epoch    51, train loss 0.044548, train error 0.95,  val loss 0.329271, percent error 9.00
# Epoch    52, train loss 0.042562, train error 0.85,  val loss 0.343875, percent error 9.00
# Epoch    53, train loss 0.040995, train error 0.85,  val loss 0.338420, percent error 9.00
# Epoch    54, train loss 0.043502, train error 0.90,  val loss 0.344973, percent error 8.70
# Epoch    55, train loss 0.038215, train error 0.75,  val loss 0.340410, percent error 9.00
# Epoch    56, train loss 0.040525, train error 0.78,  val loss 0.342502, percent error 9.60
# Epoch    57, train loss 0.038482, train error 0.68,  val loss 0.355109, percent error 9.30
# Epoch    58, train loss 0.037832, train error 0.80,  val loss 0.350568, percent error 9.60
# Epoch    59, train loss 0.038039, train error 0.78,  val loss 0.345347, percent error 8.70
# Epoch    60, train loss 0.035015, train error 0.60,  val loss 0.344558, percent error 8.80
# Epoch    61, train loss 0.033375, train error 0.65,  val loss 0.352619, percent error 8.60
# Epoch    62, train loss 0.032451, train error 0.53,  val loss 0.348430, percent error 8.80
# Epoch    63, train loss 0.031800, train error 0.57,  val loss 0.350713, percent error 8.90
# Epoch    64, train loss 0.031569, train error 0.50,  val loss 0.354182, percent error 9.00
# Epoch    65, train loss 0.031261, train error 0.50,  val loss 0.353414, percent error 8.60
# Epoch    66, train loss 0.035146, train error 0.75,  val loss 0.368773, percent error 8.80
# Epoch    67, train loss 0.030548, train error 0.53,  val loss 0.358689, percent error 8.80
# Epoch    68, train loss 0.030617, train error 0.45,  val loss 0.356118, percent error 8.30
# Epoch    69, train loss 0.030135, train error 0.43,  val loss 0.359227, percent error 8.60
# Epoch    70, train loss 0.031807, train error 0.65,  val loss 0.368229, percent error 8.80
# Epoch    71, train loss 0.030066, train error 0.45,  val loss 0.365289, percent error 9.10
# Epoch    72, train loss 0.030391, train error 0.50,  val loss 0.364220, percent error 8.70
# Epoch    73, train loss 0.028793, train error 0.47,  val loss 0.365262, percent error 9.00
# Epoch    74, train loss 0.028363, train error 0.35,  val loss 0.369761, percent error 9.00
# Epoch    75, train loss 0.029574, train error 0.60,  val loss 0.375529, percent error 8.80
# Epoch    76, train loss 0.028581, train error 0.38,  val loss 0.374178, percent error 9.10
# Epoch    77, train loss 0.029237, train error 0.40,  val loss 0.373124, percent error 9.00
# Epoch    78, train loss 0.028013, train error 0.50,  val loss 0.374358, percent error 8.70
# Epoch    79, train loss 0.027412, train error 0.45,  val loss 0.378501, percent error 8.80
# Epoch    80, train loss 0.026537, train error 0.30,  val loss 0.376777, percent error 8.80
# Epoch    81, train loss 0.026315, train error 0.30,  val loss 0.375527, percent error 8.60
# Epoch    82, train loss 0.026478, train error 0.40,  val loss 0.376119, percent error 8.60
# Epoch    83, train loss 0.026391, train error 0.38,  val loss 0.378913, percent error 8.60
# Epoch    84, train loss 0.026002, train error 0.30,  val loss 0.378372, percent error 9.00
# Epoch    85, train loss 0.025794, train error 0.30,  val loss 0.376400, percent error 8.70
# Epoch    86, train loss 0.025939, train error 0.30,  val loss 0.379322, percent error 8.90
# Epoch    87, train loss 0.025666, train error 0.30,  val loss 0.378501, percent error 8.70
# Epoch    88, train loss 0.025578, train error 0.38,  val loss 0.382811, percent error 8.70
# Epoch    89, train loss 0.025115, train error 0.32,  val loss 0.381342, percent error 8.60
# Epoch    90, train loss 0.025249, train error 0.30,  val loss 0.382480, percent error 8.80
# Epoch    91, train loss 0.024943, train error 0.30,  val loss 0.381991, percent error 8.80
# Epoch    92, train loss 0.024767, train error 0.30,  val loss 0.383172, percent error 8.50
# Epoch    93, train loss 0.024585, train error 0.28,  val loss 0.384767, percent error 8.90
# Epoch    94, train loss 0.024571, train error 0.28,  val loss 0.384480, percent error 8.60
# Epoch    95, train loss 0.024449, train error 0.35,  val loss 0.385130, percent error 8.60
# Epoch    96, train loss 0.024333, train error 0.28,  val loss 0.386170, percent error 8.60
# Epoch    97, train loss 0.024366, train error 0.28,  val loss 0.386584, percent error 9.10
# Epoch    98, train loss 0.026043, train error 0.57,  val loss 0.393906, percent error 8.60
# Epoch    99, train loss 0.023895, train error 0.30,  val loss 0.388149, percent error 8.70

# %%
print(type(data_loader))
# Out:
# <class 'torch.utils.data.dataloader.DataLoader'>
